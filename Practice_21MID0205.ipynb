# %% [markdown]
# NLP Corpus Processing

# %%
import nltk
import string
import matplotlib.pyplot as plt
from nltk.tokenize import sent_tokenize, word_tokenize
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer
from nltk import pos_tag
from wordcloud import WordCloud

# %%
# Load the corpus file (Ensure 'corpus.txt' exists in the same directory)
with open('NASA_Blog.txt', 'r', encoding='utf-8') as file:
    text = file.read()

# %%
# Sentence Tokenization
sentences = sent_tokenize(text)
print("\nSentence Tokenization:\n", sentences[:5])
# Out:
# Sentence Tokenization:
#  ['Data Being Restored from Two NASA Solar Missions\nFollowing a data outage in November 2024, some data from NASA’s SDO (Solar Dynamics Observatory) and full data from NASA’s IRIS (Interface Region Imaging Spectrograph) has been successfully restored.', 'This marks a significant step in resuming the flow of critical solar observations informing scientists and the space weather community.', 'Repairs are ongoing at the Joint Science Operations Center at Stanford University, which processes and distributes data from two of SDO’s imaging instruments.', 'Since early January, near-real time images from these instruments are being provided every 15 minutes.', 'Additionally, processing of most other SDO data has resumed, with additional processed data being distributed as system repairs progress.']

# %%
# Word Tokenization
words = word_tokenize(text)
print("\nWord Tokenization:\n", words[:20])
# Out:
# Word Tokenization:
#  ['Data', 'Being', 'Restored', 'from', 'Two', 'NASA', 'Solar', 'Missions', 'Following', 'a', 'data', 'outage', 'in', 'November', '2024', ',', 'some', 'data', 'from', 'NASA']

# %%
# Remove Stopwords
stop_words = set(stopwords.words('english'))
filtered_words = [word for word in words if word.lower() not in stop_words]

# %%
# Remove Punctuation
filtered_words = [word for word in filtered_words if word not in string.punctuation]
print("\nAfter Stopword & Punctuation Removal:\n", filtered_words[:20])
# Out:
# After Stopword & Punctuation Removal:
#  ['Data', 'Restored', 'Two', 'NASA', 'Solar', 'Missions', 'Following', 'data', 'outage', 'November', '2024', 'data', 'NASA', '’', 'SDO', 'Solar', 'Dynamics', 'Observatory', 'full', 'data']

# %%
# Stemming
stemmer = PorterStemmer()
stemmed_words = [stemmer.stem(word) for word in filtered_words]
print("\nAfter Stemming:\n", stemmed_words[:20])
# Out:
# After Stemming:
#  ['data', 'restor', 'two', 'nasa', 'solar', 'mission', 'follow', 'data', 'outag', 'novemb', '2024', 'data', 'nasa', '’', 'sdo', 'solar', 'dynam', 'observatori', 'full', 'data']

# %%
# POS Tagging
pos_tags = pos_tag(filtered_words)
print("\nPOS Tagging:\n", pos_tags[:20])
# Out:
# POS Tagging:
#  [('Data', 'NNS'), ('Restored', 'VBD'), ('Two', 'CD'), ('NASA', 'NNP'), ('Solar', 'JJ'), ('Missions', 'NNS'), ('Following', 'VBG'), ('data', 'NNS'), ('outage', 'NN'), ('November', 'NNP'), ('2024', 'CD'), ('data', 'NN'), ('NASA', 'NNP'), ('’', 'NNP'), ('SDO', 'NNP'), ('Solar', 'NNP'), ('Dynamics', 'NNP'), ('Observatory', 'NNP'), ('full', 'JJ'), ('data', 'NNS')]

# %%
# Generate Word Cloud
wordcloud = WordCloud(width=800, height=400, background_color='white').generate(' '.join(filtered_words))

plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.show()
